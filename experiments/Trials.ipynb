# %%
import os 
import json 
import torch
import numpy as np 
from PIL import Image
from evaluate import load
import matplotlib.pyplot as plt
from datasets import load_dataset 
from tqdm.notebook import tqdm
from transformers import BlipProcessor, BlipForConditionalGeneration, AutoProcessor, AutoModelForCausalLM,  ViTImageProcessor, AutoTokenizer

# %%
model_configs = {
    "blip": {
        "saved_checkpoint": "checkpoints/models/blip/",
        "processor": BlipProcessor, 
        "pretrained_path": "Salesforce/blip-image-captioning-large", 
        "inference_model": BlipForConditionalGeneration
    }, 
    "git": {
        "saved_checkpoint": "checkpoints/models/git/",
        "processor": AutoProcessor, 
        "pretrained_path": "microsoft/git-base", 
        "inference_model": AutoModelForCausalLM
    },
    "vit": {
        "saved_checkpoint": "checkpoints/models/vit/",
        "processor": [ViTImageProcessor, AutoTokenizer], 
        "pretrained_path": ["nlpconnect/vit-gpt2-image-captioning", "microsoft/git-base"], 
        "inference_model": AutoModelForCausalLM
    }
}

# %%
DATA_PATHS = {
    "annotated_set_dir": "prompts/",
    "inference_set_dir": "complete_image_set/inference/"
}

# %%
def load_models(model_configs):
    models = {key: {} for key in model_configs.keys()}

    for model_name in model_configs.keys(): 
        ckpt, processor, pretrained_path, inf_model = model_configs[model_name].values()

        models[model_name]["model"] = inf_model.from_pretrained(ckpt) 
        models[model_name]["processor"] = [
            processor[0].from_pretrained(pretrained_path[0], kwargs="padding"), 
            processor[1].from_pretrained(pretrained_path[1], kwargs="padding")
        ] if model_name == "vit" else processor.from_pretrained(pretrained_path, kwargs="padding")
        
    return models

# %%
models = load_models(model_configs)

# %%
# Trials setup
inference_configs = [
    {
        "temperature": 0.8,
        "top_k": 50, 
        "do_sample": True
    }, 
    {
        "temperature": 0.5,
        "top_k": 100, 
        "do_sample": True
    },
    {
        "temperature": 0.7, 
        "top_k": 150, 
        "do_sample": True, 
        "top_p": 0.9
    }, 
    {
        "temperature": 0.3,
        "top_k": 10, 
        "do_sample": True, 
        "top_p": 0.3
    }, 
    {
        "temperature": 0.8, 
        "top_k": 20, 
        "do_sample": True, 
        "num_beams": 5
    }, 
    {
        "top_k": 20, 
        "do_sample": False, 
        "num_beams": 5,
        "num_beam_groups": 5, 
        "repetition_penalty": 1.2, 
        "diversity_penalty": 2.0
    }, 
    {
        "top_k": 20, 
        "do_sample": False, 
        "num_beams": 5,
        "num_beam_groups": 5,
        "repetition_penalty": 1.5, 
        "diversity_penalty": 1.0
    }, 
    {
        "top_k": 20, 
        "do_sample": False, 
        "num_beams": 5,
        "num_beam_groups": 5,
        "repetition_penalty": 1.8, 
        "diversity_penalty": 1.5
    }, 
]

# %%
# Testing configs block 
image = Image.open(DATA_PATHS["inference_set_dir"] + "404.png")
model, processor = models["git"].values()
pixel_values = processor(images=image, return_tensors="pt").pixel_values

for trial in inference_configs:   
    generated_ids = model.generate(pixel_values=pixel_values, max_length=200, num_return_sequences=5, **trial)
    processor.batch_decode(generated_ids, skip_special_tokens=True)

# %%
def load_config_comparison(model_name, file_name): 
    image_path = DATA_PATHS["inference_set_dir"] + file_name
    inference_dict = {} 
    image_processor = None 
    model, processor = models[model_name].values()
    image = Image.open(image_path)

    if model_name == "vit": 
        image_processor, processor = processor
    
    for index, trial in enumerate(inference_configs):                     
        pixel_values = image_processor(images=image, return_tensors="pt").pixel_values if model_name == "vit" else processor(images=image, return_tensors="pt").pixel_values
        generated_ids = model.generate(pixel_values=pixel_values, max_length=200, num_return_sequences=5, **trial)

        inference_dict[index] = processor.batch_decode(generated_ids, skip_special_tokens=True)

    
    return inference_dict

# %%
def print_inferences(model_name, file_name): 
    inference = load_config_comparison(model_name, file_name) 
    
    for trial_number, captions in inference.items(): 
        print("Trial #: ", trial_number)  
    
        for caption in captions: 
            print(caption) 
    
        print()

# %% [markdown]
# #### GIT inference config tuning

# %%
print_inferences("git", "404.png")
# Out:
# Trial #:  0
# design an elegant about me page with a white background, add subtle elements to the page design
# design an about us page with vertical stacked layout
# about us page design with centered content
# design an about me page with simple text and a white background, splashes of color, shapes arranged overlaid in a 3 column shape with 2 columns
# design an attractive, modern landing page design for a furniture brand with an even text - image split layout
#
# Trial #:  1
# design an elegant about me page design with centered text
# design a simple about me page with minimal text and white color scheme
# design a simple yet elegant about me page with minimal text
# design a simple about me page with a white background, and black font color, with a single image in a straight border
# design a simple about me page with a white background, and black font color, with a single image placed vertically stacked layout
#
# Trial #:  2
# design a simple about us page with minimal text
# design a simple about us page with a single image with a white background, with a single image column and section content in a circular shape with a single image section
# design a simple about me page with a dark color scheme
# about us page design with vertically stacked layout
# about us page design for hotel landing page design
#
# Trial #:  3
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
#
# Trial #:  4
# design a simple about me page with a minimalistic and elegant look
# design an elegant about me page design with a white background, and black font color, with a single image split layout, for an artistic about me page design
# design an elegant about me page design with a white background and black font color, with a single image split into 2 sections
# design an elegant about me page design with a white background, and black font color, with a single image split into 2 sections
# design an elegant about me page design with minimal text
#
# Trial #:  5
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
# create an elegant landing page design for your photography brand with a white background and black font color, with a single image column that takes up most of the page design
# landing page design for educational application with card layout
# design an about us page with a white background, and black font color, with a single image split layout, for content and image
# about us page design with centered text
#
# Trial #:  6
# landing page design for educational application with card layout
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
# design an about us page with a white background, and black font color, with a single image split layout, for content and image
# about us page design with centered text
# design a simple 404 page with minimal text
#
# Trial #:  7
# landing page design for educational application with card layout
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
# design an about us page with a white background, and black font color, with a single image split layout
# create an elegant landing page design for a furniture brand with 3d card effects
# about us page design with centered text

# %%
print_inferences("git", "about_test.jpg")
# Out:
# Trial #:  0
# design an about me page with a twist, dynamic, with a split as the image of another section arranged in 2 sections
# design a simple about me page with a minimalistic and elegant look with white typography against a background, with a 2 column layout, a vertically stacked layout for content
# design a minimalistic and elegant about me page design with an even image of the product at the right and the image of the page, with a horizontal card section in a horizontal card layout
# about us page design for an animal info application with a white background, and a profile image arranged in eight sections
# design a cool about me page with a single image, with a white background, add an actual text to the right and another section in the left side
#
# Trial #:  1
# landing page design for finance app with a white background, and red color scheme
# design a sleek about us page with minimal text
# design a simple about me page with a white background, with a colorful animated illustration of space in a circular shape with a prominent typography against a white background
# design a simple about me page with a white background, with a horizontal card layout, with centered content, a navbar menu, and social links about me page design
# design an about me page with a white background, and black font color, with a single image column that takes up most of the page design
#
# Trial #:  2
# design a minimalistic and elegant about me page design for a web design with a white background, splashes of color overlaid and social links, minimal section content, minimal section content
# design an about us page with centered text, centered navbar menu, single section
# design a simple and elegant about me page design for a portfolio site with a minimalistic and elegant look
# design a simple about us page with a striking image, with a white background and red typography against a white background
# design an about me page with minimal text
#
# Trial #:  3
# design a simple about me page with a white background, with a single image column and centered content in a horizontal card layout
# design a simple about me page with a white background, with a single image column and centered content in a horizontal card layout
# design a simple about me page with a white background, with a single image column and centered content in a horizontal card layout
# design a simple about me page with a white background, with a single image column and centered content in a horizontal card layout
# design a simple about me page with a white background, with a single image column and centered content in a horizontal card layout
#
# Trial #:  4
# design a simple about me page with a minimalistic and elegant look
# design a simple about me page with a minimalistic and elegant look
# design a simple about me page with a white background, and black font color, with a single image column that takes up most of the page design
# design a simple about me page with a white background, and black font color, with a single image column that takes up most of the page design for a portfolio site
# design a simple about me page with a white background, and black font color, with a single image column that takes up most of the page design for an interior design
#
# Trial #:  5
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
# landing page design for educational application with card layout
# design an about us page with a white background, and black font color, with a single image split layout
# about us page design with centered content
# create an elegant landing page design for a furniture brand with dark blue and white section backgrounds, and orange accents with a white background, add a subtle twist
#
# Trial #:  6
# landing page design for educational application with card layout
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
# design an about us page with a white background, and black font color, with a single image split layout
# about us page design with centered content
# design a simple about me page with an even text - image split layout
#
# Trial #:  7
# landing page design for educational application with card layout
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
# create an elegant landing page design for a furniture brand with dark blue and white section backgrounds, and orange accents with a purple color scheme
# design an about us page with a white background, and black font color, with a single image split layout
# about us page design with centered content

# %%
print_inferences("git", "about_us_test.png")
# Out:
# Trial #:  0
# design an about us page with a dark color scheme, with centered text overlaid, single section, and split into 2 sections
# design an about me page with an even text - image split layout for a web design with centered content
# design a simple about me page with a simple yet elegant look
# landing page design for hotel brand with card layout
# design a full screen hero section for an empty food plate with a white background and black font color, with a centered content in a horizontal grid
#
# Trial #:  1
# design a simple about me page with a single image, with a curved background, with a white section, and black font color, with a single image column and section content left side by side
# design a simple and neat about me page with a white background, add a colorful animated animated image to add focus and circle shaped background to add links to other pages in a horizontal card layout
# design a simple and neat about me page design for a project with a vertically stacked layout
# landing page design for educational application with card layout
# design an about us page with an animated illustration
#
# Trial #:  2
# design a dynamic car wash landing page with a white background, and red color scheme
# landing page design for educational application with card layout
# design a landing page for your photography brand with a futuristic digital art illustration
# design an about us page with text and image arranged in 2 sections
# design a simple and neat text only based white color schemed 404 page design
#
# Trial #:  3
# design a simple about me page with a white background, with a single image column and centered content in a horizontal card layout
# design a simple about me page with a white background, with a single image column and centered content in a horizontal card layout
# design a simple about me page with a white background, with a single image column and centered content in a horizontal card layout
# design a simple about me page with a white background, with a single image column and centered content in a horizontal card layout
# design a simple about me page with a white background, with a single image column and centered content in a horizontal card layout
#
# Trial #:  4
# design a simple about me page with a minimalistic and elegant look for a portfolio site with a white background and black font color, with a single image column that takes up most of the page
# design a simple about me page with a minimalistic and elegant look for a portfolio site with a white background, and black font color, with a single image in a single image - text split
# design a simple about me page with a minimalistic and elegant look for a portfolio site with a white background and black font color, with a single image column that takes up most of the page
# design a simple about me page with a minimalistic and elegant look for a portfolio site with a white background and black font color, with a single image column that takes up most of the page
# design a simple about me page with a minimalistic and elegant look for a portfolio site with a white background and black font color, with a single image column that takes up most of the page
#
# Trial #:  5
# create an elegant landing page design for your photography brand with a white background, and black font color, with a single image column that takes up most of the page design
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
# landing page design for educational application with card layout
# design a cool ui for a food based brand with a white background, and black font color, with a single image column that takes up most of the page, add links to other pages in
# about us page design with centered content
#
# Trial #:  6
# landing page design for educational application with card layout
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
# design an about us page with a white background, and black font color, with a single image split layout
# about us page design with centered content
# create an elegant landing page design for a furniture brand with dark blue and white section backgrounds, and orange accents with a white background, add a subtle twist
#
# Trial #:  7
# landing page design for educational application with card layout
# design a simple about me page with a white background, and black font color, with a single image split into 2 sections
# create an elegant landing page design for a furniture brand with dark blue and white section backgrounds, and orange accents with a purple color scheme
# design an about us page with a white background, and black font color, with a single image split layout
# about us page design with centered content

# %% [markdown]
# #### BLIP inference config tuning

# %%
Image.open(DATA_PATHS["inference_set_dir"] + "404.png")

# %%
print_inferences("blip", "404.png")
# Out:
# Trial #:  0
# simple white background, alternating text for the heading of the page
# simple text art based 404 page design with a white background and a circular logo followed by the section content
# create a captivating about me page design with white and grey color scheme, huge image section, and black typography
# design a simple white and grey color schemed 404 section content that is centered on the page with a circular layout that gives off an animated twist and artistic twist
# create a simple 404 page design with a white theme, black font and a circle shaped background with an abstract image
#
# Trial #:  1
# simple white background, centered text, and a circular shape, gives off a modern vibe for the page design
# create an elegant 404 page design with a white background, giant typography, and a circular section title that is centered with a black typography and a circular image
# create a simple text graphic based 404 page design with a white background and a circular graphic arranged into a circle, with a black section content that is centered and the image placed into the text
# simple white background, centered navbar, and a black typography, centered text, add a circle shape to add focus and a capt to the theme, add emphasis to add focus and focus
# design a simple 404 page with a white background, a circular shape, and a black font
#
# Trial #:  2
# simple text based 404 page design with a white background and a circular section that has a circular image of the page in black font
# white background, minimal section title, centered logo, and a circular shape, centered navbar, centered content, large typography, for
# design a simple white and grey color palette with a circle based graphic that is centered on the page
# create a white and grey color palette with a cool twist on the page, incorporating a circular image section with a circular background graphic
# design a simple white and grey color schemed 404 page design with a centered section that has a circular illustration of a circle and a central section that is centered with a circle
#
# Trial #:  3
# create a simple 404 page design with a white background, black typography and a circular shape
# create a simple 404 page design with a white background, black typography and a circular shape
# create a simple 404 page design with a white background, black typography and a circular shape
# create a simple 404 page design with a white background, black typography and a circular shape
# create a simple 404 page design with a white background, black typography and a circular shape
#
# Trial #:  4
# create a simple 404 page design with a white background, black typography and a circular section title that is centered on the page with a circular navbar
# create a simple 404 page design with a white background, black typography, and a circular shape
# create a simple 404 page design with a white background, black typography, and a circular shape
# create a simple 404 page design with a white background, black typography and a circular section title
# create a simple 404 page design with a white background, black typography and a circular section title that is centered on the page
#
# Trial #:  5
# create a simple 404 page design with a white background, black typography and a circular shape
# create an elegant white and grey color scheme for a 404 page design with a circular shape, centered with a navbar and a black font that is centered with a circular section content
# design a white and black color schemed 404 page design with a circular shape, centered with a navbar and a black font
# white background, minimal section content, centered navbar, large typography, centered logo, centered text, minimal section for content, minimal section content, minimal section content, minimal section content, white background, minimal section content, minimal section content, minimal section content, minimal section design, minimal section, minimal section, minimal section, minimal section, text, minimal section, minimal, minimal,
# simple text based 404 page design
#
# Trial #:  6
# create a simple 404 page design with a white background, black typography and a circular shape
# simple text based 404 page design with a white background and a circular shape
# design a white and black color schemed 404 page with an elegant twist, centered navbar and a circular shape
# create an elegant 404 page design with white and black color scheme, circular section titles, and a circular background that gives off a cool vibe for the text and image
# white background, minimal section content, centered navbar, large typography, centered logo, centered text, minimal section for content, minimal section content, minimal section content, minimal section content, white background, minimal section content, minimal section content, minimal section content, minimal section design, minimal section, minimal section,
#
# Trial #:  7
# create a simple 404 page design with a white background, black typography and a circular shape
# create an elegant white and grey color scheme for a 404 page design with a circular shape, centered with a navbar and a black font that is centered with a circular section content
# design a white and black color schemed 404 page with an elegant twist
# white background, minimal section content, centered navbar, large typography, centered logo, black font, and a white background, add
# simple text based 404 page design with a white background and a circular shape

# %%
print_inferences("blip", "about_test.jpg")
# Out:
# Trial #:  0
# simple about me page, about us section, about us page, about us page, about us page design, about us page layout, about us page design, about us page page
# develop an elegant landing page design for an educational application with a grey and white theme, a black and white section, and a yellow section that has images of people working with laptop in a laptop and a laptop as background
# create an elegant landing page ui for a furniture brand with a black and white section backgrounds, rectangular, with 2 sections that are too stacked and add for page page
# create an elegant about us page design with an even text - navigating section, white background, and black and white color scheme
# create an elegant landing page for a card game with a 2 - panel about me page design
#
# Trial #:  1
# create an elegant landing page ui for an interior design brand with an elegant grey and white theme
# create an elegant landing page design for a furniture brand with an elegant interior color palette with black and white sections and a yellow section that gives off an elegant vibe of the page content and modern action
# create an elegant landing page design for a furniture brand with a white and grey theme and yellow accents
# create an elegant landing page ui for a furniture brand with an image section that is centered on the page and a black and white color scheme
# create an about us page with a 2 - column layout and a white - and - black - white - color scheme
#
# Trial #:  2
# landing page design for an interior design brand with 3 sections
# about us page
# create an elegant about us page for a graphic brand with an image section - by - page and a greyscale background that gives off an elegant vibe and white space
# create an elegant landing page design for a furniture brand with a white and grey color scheme and lots of images of their designs
# simple about us page with grey and white theme
#
# Trial #:  3
# create an elegant landing page design for a furniture brand with a grey and white theme, rectangular, with images of interior designs and text
# create an elegant landing page design for a furniture brand with a grey and white theme, rectangular, with images of interior designs and text
# create an elegant landing page design for a furniture brand with a grey and white theme, rectangular, with images of interior designs and text
# create an elegant landing page design for a furniture brand with a grey and white theme, rectangular, with images of interior designs and text
# create an elegant landing page design for a furniture brand with a grey and white theme, rectangular, with images of interior designs and text
#
# Trial #:  4
# create an elegant landing page design for an interior design brand with a grey and white theme, rectangular, with images of interior designs and text
# create an elegant landing page design for an interior design brand with a grey and white theme, rectangular, with images of interior designs
# create an elegant landing page design for an interior design brand with a black and white color scheme, rectangular, with images of interior designs and text
# create an elegant landing page design for an interior design brand with a black and white color scheme, rectangular, with images of interior designs
# create an elegant landing page design for an interior design brand with a black and white color scheme and 2 sections with images of interior designs
#
# Trial #:  5
# create an elegant landing page design for a furniture brand with a grey and white theme, rectangular, with images of interior designs and text
# landing page design for an interior design brand with a grey and white theme
# simple about us page with 2 sections, black and white color scheme, rectangular image and grid layout, and yellow accents
# about us page with 2 sections, white background, black and yellow accents
# create an about us page with a grey and white theme, black and white images, and a 2 - columned layout
#
# Trial #:  6
# create an elegant landing page design for a furniture brand with a grey and white theme, rectangular, with images of interior designs and text
# landing page design for an interior design brand with a grey and white theme
# create an elegant landing page design for an interior design brand with a grey and white theme, rectangular, with images of interior designs and text
# simple about us page with 2 sections, black and white color scheme, rectangular image section, and yellow accents
# about us page with 2 sections, white background, black and yellow accents, and a 2 - columned layout
#
# Trial #:  7
# landing page design for an interior design brand with a grey and white theme
# create an elegant landing page design for a furniture brand with a grey and white theme, rectangular, with images of interior designs and text
# simple about us page with 2 sections, black and white color scheme, rectangular image section, and yellow accents
# about us page with 2 sections, white background, black and yellow accents
# create an about us page with a grey and white theme, black and white images, and a 2 - columned layout

# %%
print_inferences("blip", "about_us_test.png")
# Out:
# Trial #:  0
# medical application landing page
# medical application landing page design with a clean white background, 2 sections with medical themed illustrations and a blue rectangular background
# medical application landing page
# sports academy, sports section, sports academy, sports landing page, sports sports page, sports academy, sports blog, sports page, sports academy site
# 3 sections in a white background themed catalog page
#
# Trial #:  1
# medical application landing page with 2 sections
# medical application landing page with card layout
# medical application landing page
# medical application landing page
# medical application landing page design with white background and colorful illustrations
#
# Trial #:  2
# medical application landing page design with 2 sections with an image carousel, white background, and colorful illustrations
# white, blue color palette, education theme, education page, educational section, school theme, school themed, sports themed page, sports themed page, sports themed page, sports themed, sports theme, sports theme, sports themed page, sports themed page, sports themed page, sports themed page, sports, sports theme, sports theme, sports, sports
# medical application landing page with medical application section, vertically stacked layout, white background and card layout
# medical application landing page design with a 2 - column layout with images of people working on a laptop
# medical application landing page design with 3 sections
#
# Trial #:  3
# medical application landing page design with white background and colorful illustrations
# medical application landing page design with white background and colorful illustrations
# medical application landing page design with white background and colorful illustrations
# medical application landing page design with white background and colorful illustrations
# medical application landing page design with white background and colorful illustrations
#
# Trial #:  4
# medical application landing page design with 2 sections
# medical application landing page design with card layout
# medical application landing page design with a white background, 2 sections with images of people in a medical application
# medical application landing page design with white background and colorful illustrations
# medical application landing page design with a white background, 2 sections, with images of people in a medical application
#
# Trial #:  5
# medical application landing page design with white background and colorful illustrations
# sports academy about me page
# simple about us page with white background, 2 sections, with images of people in a playroom
# create an elegant landing page design for a educational application with white and yellow theme, rectangular layout, and 2 sections
# white background, 2 sections, with images of people in a playbook
#
# Trial #:  6
# medical application landing page design with white background and colorful illustrations
# create an elegant landing page design for a educational application with white background and colorful illustrations
# sports academy about me page
# simple about us page with white background, 2 sections, with images of people in a playroom
# medical application landing page with a white theme, 2 sections, and a card about me section
#
# Trial #:  7
# medical application landing page design with white background and colorful illustrations
# sports academy about me page
# create an elegant landing page design for a educational application with white and yellow theme, rectangular layout, and 2 sections
# simple about us page with white background, 2 sections, and a card layout
# medical application landing page

# %% [markdown]
# #### VIT inference config tuning

# %%
print_inferences("vit", "404.png")
# Out:
# Trial #:  0
# 404 page design with a na stacked
# design a section for a web page with a 404 section, 3d image, illustration with a single section for a na type
# 404 page design with a dinosaur with a cartoon face and a white profile layout, with a black font and a single image of a dinosaur in a purple font
# design a 404 page with just a section of text that is on a column
# about me page design with a white background, black text and a dark image of a person wearing a headband and holding a white object
#
# Trial #:  1
# design a 404 page with a dark color palette, white text and a white background, with a black image and a white image that has a minimal image and a white image of a purple and
# landing page design for a 404 page design with a single section of text
# dark landing page design for a furniture brand with a minimalistic illustration of a dinosaur image and a white background
# design a minimalistic about us page with a dark theme with a white background, a white typography with a dark image and a white image
# 404 page design with a minimalistic image of a dinosaur with a dark theme, a white background and a dark purple typography, and a white image of a dinosaur illustration
#
# Trial #:  2
# design a 404 page with a white background, a purple background, a black and white image, and a white image of a section with a single section content
# about us page design with a 3 section layout
# design a 404 page ui with a dinosaur theme, a single section with a cartoon illustration of a dinosaur theme with a na na on a white background, and a cartoon image of a white dinosaur
# design a 404 page with a dark background, with a dark image of an animal with a white background, an animated image and a black typography
# simple about me page design with a half page and half section layout
#
# Trial #:  3
# design a 404 page with a white background, a dark blue and white image, a single section with a single section with a single section for text
# design a 404 page with a white background, a dark blue and white image, a single section with a single section with a single section for text
# design a 404 page with a white background, a dark blue and white image, a single section with a single section with a single section for text
# design a 404 page with a white background, a dark blue and white image, a single section with a single section with a single section for text
# design a 404 page with a white background, a dark blue and white image, a single section with a single section with a single section for text
#
# Trial #:  4
# design a simple about me page design for a landing page design with a white background, a single section with a single section with a 2 column layout for a landing page design
# design a simple about me page design for a landing page design with a white background, a single section with a single section with a 2 column layout for a landing page design with 2 sections
# design a simple about me page design for a landing page design with a white background, a single section with a single section for text and image
# design a simple about me page design for a landing page design with a white background, a single section with a single section with a 2 column layout for a landing page design with a 2 column
# design a simple about me page design for a landing page design with a white background, a single section with a single section with a 2 column layout for a landing page design with a cartoon image
#
# Trial #:  5
# 404 page design with a white background, a black and white image, a single section with a single section of text that is centered on a white background
# about us page design for a landing page with an image of a dinosaur
# design a 404 page with a white background, a dark blue and white image, a single section with a single section of text that is centered on a single section with a black image
# a simple about us page design with a minimalistic illustration of an off - white, black and white color scheme
# create an elegant landing page for a furniture brand with a minimalistic design
#
# Trial #:  6
# 404 page design with a white background, a black and white image of a dinosaur
# a simple about us page design with an image of a dinosaur
# about us page design with a single section of text
# design a simple about me page with a white background, a dark image and a single image of an animal themed landing page
# design a 404 page with a white background, a dark blue and white image of a dinosaur with a black background, a single section that has a cartoon image
#
# Trial #:  7
# 404 page design with a white background, a black and white image of a dinosaur
# design a 404 page with a white background, a dark blue and white image of a dinosaur in a circle
# design an about us page with a white background, a dark blue and white image of a dinosaur themed landing page with a single section for text
# about us page design with a single section of text
# a simple yet elegant landing page design for an about us page with a single section and image of text

# %%
print_inferences("vit", "about_test.jpg")
# Out:
# Trial #:  0
# landing page design with an image of a yellow and white theme
# about us page design with minimal section content
# about us page design with yellow background, minimalistic typography with a yellow color palette, black and white
# yellow and black color scheme with white text and a black background, 2 columns
# yellow ui ui for a website landing page design with right - curve shapes and white text overlay
#
# Trial #:  1
# yellow color scheme with white background, black and white color scheme, with a black theme, and a white text layout
# yellow and black color scheme, with a yellow background, a white text and a black image, the page layout has a grid layout for a yellow and black color scheme, and a white image
# a simple about us page design with yellow and black color scheme
# about us page design with yellow and black color scheme, white background, and a simple yellow section
# yellow and black color scheme with a yellow background, white text and a black typography
#
# Trial #:  2
# design a simple about us page with yellow and black color scheme
# about us page design with a yellow background, blue and white color palette, and a white background with images of people
# yellow background, white background, black and white color scheme, with white typography and a yellow image
# yellow and black color scheme with white background and dark blue accents, white text and a yellow background, a single section of a page layout for an image
# yellow and black color palette
#
# Trial #:  3
# yellow and black color scheme with white background, minimalistic typography, and a yellow background, with a white and black color scheme
# yellow and black color scheme with white background, minimalistic typography, and a yellow background, with a white and black color scheme
# yellow and black color scheme with white background, minimalistic typography, and a yellow background, with a white and black color scheme
# yellow and black color scheme with white background, minimalistic typography, and a yellow background, with a white and black color scheme
# yellow and black color scheme with white background, minimalistic typography, and a yellow background, with a white and black color scheme
#
# Trial #:  4
# yellow and black color scheme
# yellow and black color scheme
# yellow and black color scheme with white background and black typography
# yellow and black color scheme with white background and black typography for a landing page design with a yellow and black color scheme
# yellow and black color scheme with white background and black typography for a landing page design
#
# Trial #:  5
# about us page design with yellow and black color scheme
# yellow and black color scheme with white background, minimalistic typography, and a yellow background
# 404 page design with yellow color scheme, white and black color scheme, with a yellow background, and a white image of a yellow section with a white and black color scheme
# create an elegant landing page design for a furniture brand with white and black color scheme, with a yellow background, a white and black color scheme, and a yellow section
# design a simple about us page with a yellow background, a white and black color scheme, and a yellow section with a white image of a grid layout
#
# Trial #:  6
# about us page design with yellow and black color scheme
# design a simple about us page with yellow and black color scheme
# 404 page design with yellow color scheme, white background and black typography
# yellow and black color scheme with white background, minimalistic typography, and a yellow background
# yellow and black color scheme
#
# Trial #:  7
# about us page design with yellow and black color scheme
# design a simple about us page with yellow and black color scheme
# 404 page design with yellow color scheme, white background and black typography
# yellow and black color scheme with white background, minimalistic typography, blue backgrounds, and a yellow section with a white image of a menu
# yellow color scheme with white background, blue and white accents, black text section, and a yellow image

# %%
print_inferences("vit", "about_us_test.png")
# Out:
# Trial #:  0
# themed landing page design for a furniture brand in a 2 column layout with a white and black color palette and 2 column layouts
# design a simple about me page design for a food based brand
# simple ui design for a restaurant with white and dark blue color scheme
# design a simple about me page with simple designs
# design a 404 section with a green background, a white background, two sections for images, a white image and an image of a green image, a white background, a brown circle with a
#
# Trial #:  1
# design a simple about us page with a nab theme and 2 sections
# design a simple about me page design for a website
# about us page design with a green background, white and blue color scheme
# design a simple about me page design with a simple typography based image in a grid with a white background, with a purple and white color scheme
# about us page design with 2 sections
#
# Trial #:  2
# about us page design with 2 columns, 2 columns, and a section with 4 columns for a simple text layout
# about us page design with white background, green and yellow color scheme, 2 column layouts
# design a simple about me page design for a blog about me page design with a colorful image of a dinosaur
# cute and colorful about me page design with a yellow background, 2 sections stacked and a white background, a green and blue color palette, and a white image
# design a landing page with a fun ui for an interior design brand
#
# Trial #:  3
# design a simple about me page design with a colorful image of a plant based app
# design a simple about me page design with a colorful image of a plant based app
# design a simple about me page design with a colorful image of a plant based app
# design a simple about me page design with a colorful image of a plant based app
# design a simple about me page design with a colorful image of a plant based app
#
# Trial #:  4
# design a simple about me page design for a blog about me page design
# design a simple about me page design for a blog about me page design with a white background, green and blue color scheme
# design a simple about me page design for a blog about me page design with a white background, green and blue color palette
# design a simple about me page design for a furniture brand
# design a simple about me page design for a blog about me page design with a white background, green and blue color scheme, with a 2 column layout
#
# Trial #:  5
# design a simple about me page with a colorful image of a plant based app
# about us page design with a colorful image of a plant based content
# simple about me page design with a white background, a green and blue color palette, and a white image of a nar - based landing page design
# a simple about us page design for an interior design brand with a colorful image of a plant based app
# colorful landing page design for a furniture brand with an image of two sections
#
# Trial #:  6
# about us page design with a colorful image of two sections
# design a simple about me page with a colorful image of a plant based app
# simple about me page design with a white background, green and blue color scheme, and a single image of the content
# a simple about us page design with an image of a plant based content
# design a cool ui for a food brand
#
# Trial #:  7
# simple about me page design with a white background, green and blue color scheme, and 2 sections of the image
# about us page design with a colorful image of two sections
# design a simple about me page with a colorful image of a plant based app
# a simple about us page design with an image of two sections
# design a cool ui for an interior design brand with a colorful image of a plant based app
